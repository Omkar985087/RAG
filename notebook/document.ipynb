# %% [markdown]
# Data Ingestion

# %%
#document datastructure

from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main text context i am using to create RAG",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author":"Omkar Kadam",
        "data_created":"2026-05-18"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Omkar Kadam', 'data_created': '2026-05-18'}, page_content='this is the main text context i am using to create RAG')
